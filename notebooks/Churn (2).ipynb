# %%
pip install torch_geometric
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.13.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2025.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.2.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch_geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch_geometric) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch_geometric) (2025.10.5)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->torch_geometric) (4.15.0)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.5 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.7.0

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch_geometric.data import Data
from torch_geometric.nn import SAGEConv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import roc_auc_score, precision_score, recall_score, f1_score
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import joblib
import pickle
import os
import wandb
import warnings
warnings.filterwarnings('ignore')

# %%
DATA_PATH = "/content/group_project/clean_data.csv"
SAVE_DIR = "/content/group_project/"
OBSERVATION_DAYS = 30
PREDICTION_DAYS = 31

# %%
try:
    from google.colab import userdata
    WANDB_API_KEY = userdata.get('WANDB')
    wandb.login(key=WANDB_API_KEY)
except:
    pass
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: katrinpochtar to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# # Data split

# %%
def create_temporal_dataset(df, observation_days=30, prediction_days=31):
    df = df.copy()
    df['event_dt'] = pd.to_datetime(df['event_dt'])

    max_date = df['event_dt'].max()
    min_date = df['event_dt'].min()

    observation_end = max_date - pd.Timedelta(days=prediction_days)
    observation_start = observation_end - pd.Timedelta(days=observation_days)

    if observation_start < min_date:
        observation_start = min_date

    print(f"\nObservation: {observation_start.date()} to {observation_end.date()}")
    print(f"Prediction: {observation_end.date()} to {max_date.date()}")

    observation_data = df[
        (df['event_dt'] >= observation_start) &
        (df['event_dt'] < observation_end)
    ].copy()

    prediction_data = df[df['event_dt'] >= observation_end]

    active_in_observation = set(observation_data['device_id'].unique())
    active_in_prediction = set(prediction_data['device_id'].unique())
    churned_users = active_in_observation - active_in_prediction

    print(f"Users: {len(active_in_observation):,} | Churned: {len(churned_users):,} ({len(churned_users)/len(active_in_observation):.1%})")

    churn_labels = {uid: 1 if uid in churned_users else 0 for uid in active_in_observation}

    return observation_data, churn_labels

def create_unified_split(observation_data, churn_labels, save_dir):
    user_ids = list(churn_labels.keys())
    labels = [churn_labels[uid] for uid in user_ids]

    train_val_ids, test_ids, train_val_labels, test_labels = train_test_split(
        user_ids, labels, test_size=0.2, random_state=42, stratify=labels
    )

    train_ids, val_ids, train_labels, val_labels = train_test_split(
        train_val_ids, train_val_labels, test_size=0.25, random_state=42, stratify=train_val_labels
    )

    split_data = {
        'train_ids': train_ids,
        'val_ids': val_ids,
        'test_ids': test_ids,
        'train_labels': train_labels,
        'val_labels': val_labels,
        'test_labels': test_labels
    }

    os.makedirs(save_dir, exist_ok=True)
    with open(os.path.join(save_dir, 'data_split.pkl'), 'wb') as f:
        pickle.dump(split_data, f)

    print(f"\nSplit: Train {len(train_ids):,} | Val {len(val_ids):,} | Test {len(test_ids):,}")

    return split_data

# %% [markdown]
# # Baseline

# %%
def extract_baseline_features(df, user_ids):
    event_features = df.groupby('device_id').agg({
        'event_dt': ['min', 'max', 'count'],
        'session_id': 'nunique',
        'screen': 'nunique',
        'feature': 'nunique',
        'action': 'count'
    })
    event_features.columns = ['_'.join(col).strip() for col in event_features.columns]

    event_features['days_in_window'] = (
        event_features['event_dt_max'] - event_features['event_dt_min']
    ).dt.total_seconds() / 86400

    event_features['events_per_day'] = event_features['event_dt_count'] / event_features['days_in_window'].clip(lower=1)
    event_features['sessions_per_day'] = event_features['session_id_nunique'] / event_features['days_in_window'].clip(lower=1)
    event_features['events_per_session'] = event_features['event_dt_count'] / event_features['session_id_nunique'].clip(lower=1)
    event_features['screen_diversity'] = event_features['screen_nunique'] / event_features['event_dt_count']
    event_features['feature_diversity'] = event_features['feature_nunique'] / event_features['event_dt_count']

    first_day = event_features['event_dt_min'].min()
    last_day = event_features['event_dt_max'].max()
    event_features['days_since_first_seen'] = (event_features['event_dt_min'] - first_day).dt.total_seconds() / 86400
    event_features['days_until_window_end'] = (last_day - event_features['event_dt_max']).dt.total_seconds() / 86400
    event_features['recency_in_window'] = event_features['days_until_window_end'] / event_features['days_in_window'].clip(lower=1)

    demographic = df.groupby('device_id')[['age', 'gender']].first()
    features = event_features.join(demographic, how='left')
    features = features.drop(columns=['event_dt_min', 'event_dt_max'])

    if 'gender' in features.columns:
        features = pd.get_dummies(features, columns=['gender'], prefix='gender', drop_first=False)

    features = features.fillna(features.median())
    features = features.loc[features.index.intersection(user_ids)]

    return features

def train_baseline(X_train, X_val, X_test, y_train, y_val, y_test, save_dir, config=None):
    run = wandb.init(project="churn-prediction", config=config)
    config = wandb.config

    model_type = getattr(config, 'model_type', 'xgboost')
    n_estimators = getattr(config, 'n_estimators', 200)
    max_depth = getattr(config, 'max_depth', 6)
    learning_rate = getattr(config, 'learning_rate', 0.1)

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    if model_type == 'xgboost':
        model = XGBClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            learning_rate=learning_rate,
            scale_pos_weight=len(y_train[y_train==0]) / len(y_train[y_train==1]),
            random_state=42
        )
    else:
        model = LGBMClassifier(
            n_estimators=n_estimators,
            max_depth=max_depth,
            learning_rate=learning_rate,
            scale_pos_weight=len(y_train[y_train==0]) / len(y_train[y_train==1]),
            random_state=42,
            verbose=-1
        )

    model.fit(X_train_scaled, y_train)

    y_train_prob = model.predict_proba(X_train_scaled)[:, 1]
    y_val_prob = model.predict_proba(X_val_scaled)[:, 1]
    y_test_prob = model.predict_proba(X_test_scaled)[:, 1]

    y_val_pred = (y_val_prob > 0.5).astype(int)
    y_test_pred = (y_test_prob > 0.5).astype(int)

    train_auc = roc_auc_score(y_train, y_train_prob)
    val_auc = roc_auc_score(y_val, y_val_prob)
    test_auc = roc_auc_score(y_test, y_test_prob)

    val_precision = precision_score(y_val, y_val_pred)
    val_recall = recall_score(y_val, y_val_pred)
    val_f1 = f1_score(y_val, y_val_pred)

    test_precision = precision_score(y_test, y_test_pred)
    test_recall = recall_score(y_test, y_test_pred)
    test_f1 = f1_score(y_test, y_test_pred)

    wandb.log({
        'train_auc': train_auc,
        'val_auc': val_auc,
        'val_precision': val_precision,
        'val_recall': val_recall,
        'val_f1': val_f1,
        'test_auc': test_auc,
        'test_precision': test_precision,
        'test_recall': test_recall,
        'test_f1': test_f1
    })

    joblib.dump({'model': model, 'scaler': scaler}, os.path.join(save_dir, f'baseline_{model_type}_model.pkl'))

    print(f"\n{model_type.upper()}: Train {train_auc:.3f} | Val {val_auc:.3f} | Test {test_auc:.3f}")

    run.finish()

    return {
        'model': f'Baseline-{model_type}',
        'val_auc': val_auc,
        'test_auc': test_auc,
        'test_precision': test_precision,
        'test_recall': test_recall,
        'test_f1': test_f1
    }

BASELINE_SWEEP_CONFIG = {
    'method': 'bayes',
    'metric': {'name': 'val_auc', 'goal': 'maximize'},
    'parameters': {
        'model_type': {'values': ['xgboost', 'lightgbm']},
        'n_estimators': {'values': [100, 200, 300, 500]},
        'max_depth': {'values': [3, 5, 6, 8, 10]},
        'learning_rate': {'distribution': 'log_uniform_values', 'min': 0.01, 'max': 0.3}
    }
}

# %%
def run_baseline_single():
    print("\n" + "="*80)
    print("TRAINING BASELINE (SINGLE RUN)")
    print("="*80)

    all_ids = train_ids + val_ids + test_ids
    features = extract_baseline_features(observation_data, all_ids)

    X_train = features.loc[train_ids]
    X_val = features.loc[val_ids]
    X_test = features.loc[test_ids]

    y_train = pd.Series(train_labels, index=train_ids)
    y_val = pd.Series(val_labels, index=val_ids)
    y_test = pd.Series(test_labels, index=test_ids)

    result = train_baseline(X_train, X_val, X_test, y_train, y_val, y_test, SAVE_DIR)
    return result

def run_baseline_sweep(count=10):
    print("\n" + "="*80)
    print(f"BASELINE SWEEP ({count} runs)")
    print("="*80)

    all_ids = train_ids + val_ids + test_ids
    features = extract_baseline_features(observation_data, all_ids)

    X_train = features.loc[train_ids]
    X_val = features.loc[val_ids]
    X_test = features.loc[test_ids]

    y_train = pd.Series(train_labels, index=train_ids)
    y_val = pd.Series(val_labels, index=val_ids)
    y_test = pd.Series(test_labels, index=test_ids)

    def sweep_train():
        train_baseline(X_train, X_val, X_test, y_train, y_val, y_test, SAVE_DIR)

    sweep_id = wandb.sweep(BASELINE_SWEEP_CONFIG, project="churn-prediction")
    wandb.agent(sweep_id, function=sweep_train, count=count)

# %% [markdown]
# # LSTM

# %%
class SequenceDataset(Dataset):
    def __init__(self, sequences, labels, max_len=50):
        self.sequences = sequences
        self.labels = labels
        self.max_len = max_len

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        seq = self.sequences[idx]
        label = self.labels[idx]

        if len(seq) > self.max_len:
            seq = seq[-self.max_len:]
        else:
            pad = np.zeros((self.max_len - len(seq), seq.shape[1]))
            seq = np.vstack([pad, seq])

        mask = torch.ones(self.max_len)
        if len(self.sequences[idx]) < self.max_len:
            mask[:self.max_len - len(self.sequences[idx])] = 0

        return torch.FloatTensor(seq), torch.FloatTensor([label]), mask

class AttentionLSTM(nn.Module):
    def __init__(self, input_dim, hidden_dim=128, num_layers=2, dropout=0.3):
        super(AttentionLSTM, self).__init__()

        self.lstm = nn.LSTM(
            input_dim, hidden_dim, num_layers=num_layers,
            batch_first=True, dropout=dropout if num_layers > 1 else 0,
            bidirectional=True
        )

        self.attention = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.Tanh(),
            nn.Linear(hidden_dim, 1)
        )

        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim * 2, 64),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(32, 1)
        )

    def forward(self, x, mask):
        lstm_out, _ = self.lstm(x)
        attn_weights = self.attention(lstm_out)
        attn_weights = attn_weights.masked_fill(mask.unsqueeze(-1) == 0, -1e9)
        attn_weights = F.softmax(attn_weights, dim=1)
        context = torch.sum(attn_weights * lstm_out, dim=1)
        output = self.classifier(context)
        return torch.sigmoid(output), attn_weights

def create_lstm_sequences(df, user_ids):
    df = df.sort_values(['device_id', 'event_dt'])

    le_screen = LabelEncoder()
    le_feature = LabelEncoder()
    le_action = LabelEncoder()
    le_gender = LabelEncoder()

    df['screen_enc'] = le_screen.fit_transform(df['screen'].fillna('unknown'))
    df['feature_enc'] = le_feature.fit_transform(df['feature'].fillna('unknown'))
    df['action_enc'] = le_action.fit_transform(df['action'].fillna('unknown'))
    df['gender_enc'] = le_gender.fit_transform(df['gender'].fillna('unknown'))

    df['hour'] = df['event_dt'].dt.hour / 24.0
    df['day_of_week'] = df['event_dt'].dt.dayofweek / 7.0
    df['is_weekend'] = (df['event_dt'].dt.dayofweek >= 5).astype(float)
    df['time_diff'] = df.groupby('device_id')['event_dt'].diff().dt.total_seconds() / 3600
    df['time_diff'] = df['time_diff'].fillna(0).clip(0, 24) / 24.0

    df['age_norm'] = (df['age'] - df['age'].mean()) / df['age'].std()
    df['age_norm'] = df['age_norm'].fillna(0)

    feature_cols = [
        'screen_enc', 'feature_enc', 'action_enc', 'gender_enc',
        'hour', 'day_of_week', 'is_weekend', 'time_diff', 'age_norm'
    ]

    sequences = []
    sequence_user_ids = []

    for device_id in user_ids:
        user_data = df[df['device_id'] == device_id]
        if len(user_data) > 0:
            seq = user_data[feature_cols].values.astype(np.float32)
            sequences.append(seq)
            sequence_user_ids.append(device_id)

    return sequences, sequence_user_ids, len(feature_cols)

def train_lstm(train_loader, val_loader, test_loader, input_dim, save_dir, device='cuda', config=None):
    run = wandb.init(project="churn-prediction", config=config)
    config = wandb.config

    hidden_dim = getattr(config, 'hidden_dim', 128)
    num_layers = getattr(config, 'num_layers', 2)
    dropout = getattr(config, 'dropout', 0.3)
    learning_rate = getattr(config, 'learning_rate', 0.001)
    max_epochs = getattr(config, 'epochs', 30)

    model = AttentionLSTM(input_dim=input_dim, hidden_dim=hidden_dim, num_layers=num_layers, dropout=dropout)
    model = model.to(device)

    criterion = nn.BCELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=3)

    best_val_auc = 0
    patience_counter = 0

    for epoch in range(max_epochs):
        model.train()
        train_preds, train_labels = [], []

        for sequences, labels, masks in train_loader:
            sequences, labels, masks = sequences.to(device), labels.to(device), masks.to(device)
            optimizer.zero_grad()
            outputs, _ = model(sequences, masks)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            train_preds.extend(outputs.detach().cpu().numpy())
            train_labels.extend(labels.detach().cpu().numpy())

        model.eval()
        val_preds, val_labels = [], []

        with torch.no_grad():
            for sequences, labels, masks in val_loader:
                sequences, labels, masks = sequences.to(device), labels.to(device), masks.to(device)
                outputs, _ = model(sequences, masks)
                val_preds.extend(outputs.cpu().numpy())
                val_labels.extend(labels.cpu().numpy())

        train_auc = roc_auc_score(np.array(train_labels).flatten(), np.array(train_preds).flatten())
        val_auc = roc_auc_score(np.array(val_labels).flatten(), np.array(val_preds).flatten())

        scheduler.step(val_auc)

        wandb.log({'epoch': epoch + 1, 'train_auc': train_auc, 'val_auc': val_auc})

        if (epoch + 1) % 5 == 0:
            print(f"Epoch {epoch+1:02d} | Train {train_auc:.3f} | Val {val_auc:.3f}")

        if val_auc > best_val_auc:
            best_val_auc = val_auc
            patience_counter = 0
            torch.save({
                'model_state_dict': model.state_dict(),
                'config': {'input_dim': input_dim, 'hidden_dim': hidden_dim, 'num_layers': num_layers, 'dropout': dropout}
            }, os.path.join(save_dir, 'lstm_model.pth'))
        else:
            patience_counter += 1
            if patience_counter >= 7:
                print(f"Early stopping at epoch {epoch+1}")
                break

    model.load_state_dict(torch.load(os.path.join(save_dir, 'lstm_model.pth'))['model_state_dict'])
    model.eval()
    test_preds, test_labels = [], []

    with torch.no_grad():
        for sequences, labels, masks in test_loader:
            sequences, masks = sequences.to(device), masks.to(device)
            outputs, _ = model(sequences, masks)
            test_preds.extend(outputs.cpu().numpy())
            test_labels.extend(labels.cpu().numpy())

    test_preds = np.array(test_preds).flatten()
    test_labels = np.array(test_labels).flatten()
    test_pred_binary = (test_preds > 0.5).astype(int)

    test_auc = roc_auc_score(test_labels, test_preds)
    test_precision = precision_score(test_labels, test_pred_binary)
    test_recall = recall_score(test_labels, test_pred_binary)
    test_f1 = f1_score(test_labels, test_pred_binary)

    wandb.log({
        'test_auc': test_auc,
        'test_precision': test_precision,
        'test_recall': test_recall,
        'test_f1': test_f1
    })

    print(f"\nLSTM: Best Val {best_val_auc:.3f} | Test {test_auc:.3f}")

    run.finish()

    return {
        'model': 'LSTM',
        'val_auc': best_val_auc,
        'test_auc': test_auc,
        'test_precision': test_precision,
        'test_recall': test_recall,
        'test_f1': test_f1
    }

LSTM_SWEEP_CONFIG = {
    'method': 'bayes',
    'metric': {'name': 'val_auc', 'goal': 'maximize'},
    'parameters': {
        'hidden_dim': {'values': [64, 128, 256]},
        'num_layers': {'values': [1, 2, 3]},
        'dropout': {'distribution': 'uniform', 'min': 0.1, 'max': 0.5},
        'learning_rate': {'distribution': 'log_uniform_values', 'min': 0.0001, 'max': 0.01},
        'epochs': {'value': 30}
    }
}

# %%
def run_lstm_single():
    print("\n" + "="*80)
    print("TRAINING LSTM (SINGLE RUN)")
    print("="*80)

    train_seqs, train_seq_ids, input_dim = create_lstm_sequences(observation_data, train_ids)
    val_seqs, val_seq_ids, _ = create_lstm_sequences(observation_data, val_ids)
    test_seqs, test_seq_ids, _ = create_lstm_sequences(observation_data, test_ids)

    train_seq_labels = [churn_labels[uid] for uid in train_seq_ids]
    val_seq_labels = [churn_labels[uid] for uid in val_seq_ids]
    test_seq_labels = [churn_labels[uid] for uid in test_seq_ids]

    train_dataset = SequenceDataset(train_seqs, train_seq_labels, max_len=50)
    val_dataset = SequenceDataset(val_seqs, val_seq_labels, max_len=50)
    test_dataset = SequenceDataset(test_seqs, test_seq_labels, max_len=50)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Using device: {device}")

    result = train_lstm(train_loader, val_loader, test_loader, input_dim, SAVE_DIR, device)
    return result

def run_lstm_sweep(count=20):
    print("\n" + "="*80)
    print(f"LSTM SWEEP ({count} runs)")
    print("="*80)

    train_seqs, train_seq_ids, input_dim = create_lstm_sequences(observation_data, train_ids)
    val_seqs, val_seq_ids, _ = create_lstm_sequences(observation_data, val_ids)
    test_seqs, test_seq_ids, _ = create_lstm_sequences(observation_data, test_ids)

    train_seq_labels = [churn_labels[uid] for uid in train_seq_ids]
    val_seq_labels = [churn_labels[uid] for uid in val_seq_ids]
    test_seq_labels = [churn_labels[uid] for uid in test_seq_ids]

    train_dataset = SequenceDataset(train_seqs, train_seq_labels, max_len=50)
    val_dataset = SequenceDataset(val_seqs, val_seq_labels, max_len=50)
    test_dataset = SequenceDataset(test_seqs, test_seq_labels, max_len=50)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    def sweep_train():
        train_lstm(train_loader, val_loader, test_loader, input_dim, SAVE_DIR, device)

    sweep_id = wandb.sweep(LSTM_SWEEP_CONFIG, project="churn-prediction")
    wandb.agent(sweep_id, function=sweep_train, count=count)

# %% [markdown]
# # GNN

# %%
class GraphSAGEChurn(nn.Module):
    def __init__(self, in_channels, hidden_channels=128, num_layers=2, dropout=0.3):
        super(GraphSAGEChurn, self).__init__()

        self.convs = nn.ModuleList()
        self.convs.append(SAGEConv(in_channels, hidden_channels))

        for _ in range(num_layers - 1):
            self.convs.append(SAGEConv(hidden_channels, hidden_channels))

        self.dropout = dropout

        self.classifier = nn.Sequential(
            nn.Linear(hidden_channels, 64),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(32, 1)
        )

    def forward(self, x, edge_index):
        for i, conv in enumerate(self.convs):
            x = conv(x, edge_index)
            if i < len(self.convs) - 1:
                x = F.relu(x)
                x = F.dropout(x, p=self.dropout, training=self.training)

        out = self.classifier(x)
        return torch.sigmoid(out)

def build_random_graph(n_users, edges_per_node=5):
    edge_list = []
    for i in range(n_users):
        neighbors = np.random.choice(n_users, size=min(edges_per_node, n_users-1), replace=False)
        neighbors = neighbors[neighbors != i]
        for j in neighbors:
            edge_list.append([i, j])

    return torch.tensor(edge_list, dtype=torch.long).t().contiguous()

def train_gnn(data, train_mask, val_mask, test_mask, save_dir, device='cuda', config=None):
    run = wandb.init(project="churn-prediction", config=config)
    config = wandb.config

    hidden_channels = getattr(config, 'hidden_channels', 128)
    num_layers = getattr(config, 'num_layers', 2)
    dropout = getattr(config, 'dropout', 0.3)
    learning_rate = getattr(config, 'learning_rate', 0.01)
    weight_decay = getattr(config, 'weight_decay', 5e-4)
    max_epochs = getattr(config, 'epochs', 100)

    model = GraphSAGEChurn(in_channels=data.x.size(1), hidden_channels=hidden_channels, num_layers=num_layers, dropout=dropout)
    model = model.to(device)
    data = data.to(device)

    criterion = nn.BCELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)

    best_val_auc = 0
    patience_counter = 0

    for epoch in range(max_epochs):
        model.train()
        optimizer.zero_grad()
        out = model(data.x, data.edge_index).squeeze()
        loss = criterion(out[train_mask], data.y[train_mask])
        loss.backward()
        optimizer.step()

        model.eval()
        with torch.no_grad():
            out = model(data.x, data.edge_index).squeeze()

            train_pred = out[train_mask].cpu().numpy()
            train_true = data.y[train_mask].cpu().numpy()
            val_pred = out[val_mask].cpu().numpy()
            val_true = data.y[val_mask].cpu().numpy()

            train_auc = roc_auc_score(train_true, train_pred)
            val_auc = roc_auc_score(val_true, val_pred)

        wandb.log({'epoch': epoch + 1, 'train_auc': train_auc, 'val_auc': val_auc})

        if (epoch + 1) % 10 == 0:
            print(f"Epoch {epoch+1:03d} | Train {train_auc:.3f} | Val {val_auc:.3f}")

        if val_auc > best_val_auc:
            best_val_auc = val_auc
            patience_counter = 0
            torch.save({
                'model_state_dict': model.state_dict(),
                'config': {'in_channels': data.x.size(1), 'hidden_channels': hidden_channels, 'num_layers': num_layers, 'dropout': dropout}
            }, os.path.join(save_dir, 'gnn_model.pth'))
        else:
            patience_counter += 1
            if patience_counter >= 15:
                print(f"Early stopping at epoch {epoch+1}")
                break

    model.load_state_dict(torch.load(os.path.join(save_dir, 'gnn_model.pth'))['model_state_dict'])
    model.eval()

    with torch.no_grad():
        out = model(data.x, data.edge_index).squeeze()
        test_pred = out[test_mask].cpu().numpy()
        test_true = data.y[test_mask].cpu().numpy()

    test_pred_binary = (test_pred > 0.5).astype(int)
    test_auc = roc_auc_score(test_true, test_pred)
    test_precision = precision_score(test_true, test_pred_binary)
    test_recall = recall_score(test_true, test_pred_binary)
    test_f1 = f1_score(test_true, test_pred_binary)

    wandb.log({
        'test_auc': test_auc,
        'test_precision': test_precision,
        'test_recall': test_recall,
        'test_f1': test_f1
    })

    print(f"\nGNN: Best Val {best_val_auc:.3f} | Test {test_auc:.3f}")

    run.finish()

    return {
        'model': 'GNN',
        'val_auc': best_val_auc,
        'test_auc': test_auc,
        'test_precision': test_precision,
        'test_recall': test_recall,
        'test_f1': test_f1
    }

GNN_SWEEP_CONFIG = {
    'method': 'bayes',
    'metric': {'name': 'val_auc', 'goal': 'maximize'},
    'parameters': {
        'hidden_channels': {'values': [64, 128, 256]},
        'num_layers': {'values': [1, 2, 3]},
        'dropout': {'distribution': 'uniform', 'min': 0.1, 'max': 0.5},
        'learning_rate': {'distribution': 'log_uniform_values', 'min': 0.001, 'max': 0.1},
        'weight_decay': {'distribution': 'log_uniform_values', 'min': 1e-5, 'max': 1e-3},
        'epochs': {'value': 100}
    }
}

# %%
def run_gnn_single():
    print("\n" + "="*80)
    print("TRAINING GNN (SINGLE RUN)")
    print("="*80)

    all_ids = train_ids + val_ids + test_ids
    features = extract_baseline_features(observation_data, all_ids)
    X_scaled = StandardScaler().fit_transform(features.loc[all_ids])

    edge_index = build_random_graph(len(all_ids), edges_per_node=5)

    user_id_to_idx = {uid: idx for idx, uid in enumerate(all_ids)}
    train_mask = torch.zeros(len(all_ids), dtype=torch.bool)
    val_mask = torch.zeros(len(all_ids), dtype=torch.bool)
    test_mask = torch.zeros(len(all_ids), dtype=torch.bool)

    for uid in train_ids:
        train_mask[user_id_to_idx[uid]] = True
    for uid in val_ids:
        val_mask[user_id_to_idx[uid]] = True
    for uid in test_ids:
        test_mask[user_id_to_idx[uid]] = True

    x = torch.FloatTensor(X_scaled)
    y = torch.FloatTensor([churn_labels[uid] for uid in all_ids])
    data = Data(x=x, edge_index=edge_index, y=y)

    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f"Using device: {device}")

    result = train_gnn(data, train_mask, val_mask, test_mask, SAVE_DIR, device)

    return result

def run_gnn_sweep(count=15):
    print("\n" + "="*80)
    print(f"GNN SWEEP ({count} runs)")
    print("="*80)

    all_ids = train_ids + val_ids + test_ids
    features = extract_baseline_features(observation_data, all_ids)
    X_scaled = StandardScaler().fit_transform(features.loc[all_ids])

    edge_index = build_random_graph(len(all_ids), edges_per_node=5)

    user_id_to_idx = {uid: idx for idx, uid in enumerate(all_ids)}
    train_mask = torch.zeros(len(all_ids), dtype=torch.bool)
    val_mask = torch.zeros(len(all_ids), dtype=torch.bool)
    test_mask = torch.zeros(len(all_ids), dtype=torch.bool)

    for uid in train_ids:
        train_mask[user_id_to_idx[uid]] = True
    for uid in val_ids:
        val_mask[user_id_to_idx[uid]] = True
    for uid in test_ids:
        test_mask[user_id_to_idx[uid]] = True

    x = torch.FloatTensor(X_scaled)
    y = torch.FloatTensor([churn_labels[uid] for uid in all_ids])
    data = Data(x=x, edge_index=edge_index, y=y)

    device = 'cuda' if torch.cuda.is_available() else 'cpu'

    def sweep_train():
        train_gnn(data, train_mask, val_mask, test_mask, SAVE_DIR, device)

    sweep_id = wandb.sweep(GNN_SWEEP_CONFIG, project="churn-prediction")
    wandb.agent(sweep_id, function=sweep_train, count=count)

# %% [markdown]
# # Split and save

# %%
df = pd.read_csv(DATA_PATH)
print(f"Loaded {len(df):,} events, {df['device_id'].nunique():,} users")
# Out:
# Loaded 3,360,650 events, 179,976 users

# %%
observation_data, churn_labels = create_temporal_dataset(df, OBSERVATION_DAYS, PREDICTION_DAYS)
split_data = create_unified_split(observation_data, churn_labels, SAVE_DIR)

train_ids = split_data['train_ids']
val_ids = split_data['val_ids']
test_ids = split_data['test_ids']
train_labels = split_data['train_labels']
val_labels = split_data['val_labels']
test_labels = split_data['test_labels']

print(f"Train: {len(train_ids)} users, Val: {len(val_ids)} users, Test: {len(test_ids)} users")
# Out:
# Observation: 2025-09-01 to 2025-09-30
# Prediction: 2025-09-30 to 2025-10-31
# Users: 135,860 | Churned: 59,203 (43.6%)
#
# Split: Train 81,516 | Val 27,172 | Test 27,172
# Train: 81516 users, Val: 27172 users, Test: 27172 users

# %% [markdown]
# # Test 3 models and compare

# %%
# !nvidia-smi
# Out:
# Wed Dec 17 03:54:41 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.95.05              Driver Version: 580.95.05      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off |   00000000:0B:00.0  On |                  N/A |
# |  0%   40C    P8             17W /  350W |     433MiB /  24576MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
def run_all_single():
    print("\n" + "="*80)
    print("TRAINING ALL MODELS (SINGLE RUNS)")
    print("="*80)

    results = []

    results.append(run_baseline_single())
    results.append(run_lstm_single())
    results.append(run_gnn_single())

    results_df = pd.DataFrame(results)

    print("\n" + "="*80)
    print("FINAL RESULTS")
    print("="*80 + "\n")
    print(results_df.to_string(index=False))

    results_df.to_csv(os.path.join(SAVE_DIR, 'final_results.csv'), index=False)

    best_model = results_df.loc[results_df['test_auc'].idxmax()]
    print(f"\n🏆 Best: {best_model['model']} (Test AUC: {best_model['test_auc']:.4f})")

    return results_df

# %%
run_all_single()
# Out:
# ================================================================================
# TRAINING ALL MODELS (SINGLE RUNS)
# ================================================================================
#
# ================================================================================
# TRAINING BASELINE (SINGLE RUN)
# ================================================================================
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_035456-row7m8xp</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/row7m8xp' target="_blank">magic-snowball-49</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/row7m8xp' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/row7m8xp</a>
# XGBOOST: Train 0.771 | Val 0.724 | Test 0.725
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>val_auc</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>0.72533</td></tr><tr><td>test_f1</td><td>0.65398</td></tr><tr><td>test_precision</td><td>0.58841</td></tr><tr><td>test_recall</td><td>0.736</td></tr><tr><td>train_auc</td><td>0.77102</td></tr><tr><td>val_auc</td><td>0.72407</td></tr><tr><td>val_f1</td><td>0.65115</td></tr><tr><td>val_precision</td><td>0.58445</td></tr><tr><td>val_recall</td><td>0.73505</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">magic-snowball-49</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/row7m8xp' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/row7m8xp</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_035456-row7m8xp/logs</code>
# ================================================================================
# TRAINING LSTM (SINGLE RUN)
# ================================================================================
# Using device: cuda
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_035708-vp1pgjqg</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/vp1pgjqg' target="_blank">mild-sponge-50</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/vp1pgjqg' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/vp1pgjqg</a>
# Epoch 05 | Train 0.697 | Val 0.710
# Epoch 10 | Train 0.705 | Val 0.717
# Epoch 15 | Train 0.709 | Val 0.720
# Epoch 20 | Train 0.710 | Val 0.709
# Epoch 25 | Train 0.710 | Val 0.709
# Epoch 30 | Train 0.720 | Val 0.724
#
# LSTM: Best Val 0.724 | Test 0.722
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▃▄▄▅▅▅▆▆▆▆▆▆▆▇▆▇▇▇▇▇▇▇▇▇▇▇███</td></tr><tr><td>val_auc</td><td>▁▁▃▃▄▄▄▆▆▆▄▇▆▇▇▇▇▇▇▄▇█▇▇▄▅████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.7223</td></tr><tr><td>test_f1</td><td>0.62138</td></tr><tr><td>test_precision</td><td>0.61187</td></tr><tr><td>test_recall</td><td>0.6312</td></tr><tr><td>train_auc</td><td>0.71967</td></tr><tr><td>val_auc</td><td>0.72369</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">mild-sponge-50</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/vp1pgjqg' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/vp1pgjqg</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_035708-vp1pgjqg/logs</code>
# ================================================================================
# TRAINING GNN (SINGLE RUN)
# ================================================================================
# Using device: cuda
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_040826-c2rtpb70</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/c2rtpb70' target="_blank">polar-leaf-51</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/c2rtpb70' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/c2rtpb70</a>
# Epoch 010 | Train 0.706 | Val 0.708
# Epoch 020 | Train 0.710 | Val 0.711
# Epoch 030 | Train 0.712 | Val 0.713
# Epoch 040 | Train 0.714 | Val 0.714
# Epoch 050 | Train 0.716 | Val 0.715
# Epoch 060 | Train 0.719 | Val 0.717
# Epoch 070 | Train 0.717 | Val 0.715
# Early stopping at epoch 79
#
# GNN: Best Val 0.717 | Test 0.718
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▁▁▃▄▅▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇█████▇██▇█▇████</td></tr><tr><td>val_auc</td><td>▁▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>79</td></tr><tr><td>test_auc</td><td>0.71822</td></tr><tr><td>test_f1</td><td>0.60825</td></tr><tr><td>test_precision</td><td>0.61186</td></tr><tr><td>test_recall</td><td>0.60468</td></tr><tr><td>train_auc</td><td>0.71881</td></tr><tr><td>val_auc</td><td>0.7168</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">polar-leaf-51</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/c2rtpb70' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/c2rtpb70</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_040826-c2rtpb70/logs</code>
# ================================================================================
# FINAL RESULTS
# ================================================================================
#
#            model  val_auc  test_auc  test_precision  test_recall  test_f1
# Baseline-xgboost 0.724066  0.725331        0.588414     0.736002 0.653985
#             LSTM 0.723688  0.722296        0.611871     0.631197 0.621383
#              GNN 0.717367  0.718221        0.611861     0.604679 0.608249
#
# 🏆 Best: Baseline-xgboost (Test AUC: 0.7253)
#               model   val_auc  test_auc  test_precision  test_recall   test_f1
# 0  Baseline-xgboost  0.724066  0.725331        0.588414     0.736002  0.653985
# 1              LSTM  0.723688  0.722296        0.611871     0.631197  0.621383
# 2               GNN  0.717367  0.718221        0.611861     0.604679  0.608249

# %% [markdown]
# # SWEEPS (HYPERPARAMETER TUNING)

# %%
run_baseline_sweep(count=10)
# Out:
# ================================================================================
# BASELINE SWEEP (10 runs)
# ================================================================================
# Create sweep with ID: pk7vkeqn
# Sweep URL: https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn
# wandb: Agent Starting Run: 910oo061 with config:
# wandb: 	learning_rate: 0.02794859513956267
# wandb: 	max_depth: 8
# wandb: 	model_type: lightgbm
# wandb: 	n_estimators: 200
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_042627-910oo061</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/910oo061' target="_blank">different-sweep-1</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/910oo061' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/910oo061</a>
# LIGHTGBM: Train 0.739 | Val 0.727 | Test 0.727
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>val_auc</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>0.72654</td></tr><tr><td>test_f1</td><td>0.65605</td></tr><tr><td>test_precision</td><td>0.58631</td></tr><tr><td>test_recall</td><td>0.74462</td></tr><tr><td>train_auc</td><td>0.73865</td></tr><tr><td>val_auc</td><td>0.72651</td></tr><tr><td>val_f1</td><td>0.65734</td></tr><tr><td>val_precision</td><td>0.5877</td></tr><tr><td>val_recall</td><td>0.74569</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">different-sweep-1</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/910oo061' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/910oo061</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_042627-910oo061/logs</code>
# wandb: Agent Starting Run: cxgs33l0 with config:
# wandb: 	learning_rate: 0.0927025430598389
# wandb: 	max_depth: 10
# wandb: 	model_type: lightgbm
# wandb: 	n_estimators: 500
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_042633-cxgs33l0</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/cxgs33l0' target="_blank">elated-sweep-2</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/cxgs33l0' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/cxgs33l0</a>
# LIGHTGBM: Train 0.805 | Val 0.721 | Test 0.722
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>val_auc</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>0.72237</td></tr><tr><td>test_f1</td><td>0.65372</td></tr><tr><td>test_precision</td><td>0.58793</td></tr><tr><td>test_recall</td><td>0.73609</td></tr><tr><td>train_auc</td><td>0.80496</td></tr><tr><td>val_auc</td><td>0.72076</td></tr><tr><td>val_f1</td><td>0.64916</td></tr><tr><td>val_precision</td><td>0.58317</td></tr><tr><td>val_recall</td><td>0.73201</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">elated-sweep-2</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/cxgs33l0' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/cxgs33l0</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_042633-cxgs33l0/logs</code>
# wandb: Agent Starting Run: q95ai8oh with config:
# wandb: 	learning_rate: 0.023030845994667745
# wandb: 	max_depth: 10
# wandb: 	model_type: lightgbm
# wandb: 	n_estimators: 300
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_042638-q95ai8oh</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/q95ai8oh' target="_blank">hearty-sweep-3</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/q95ai8oh' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/q95ai8oh</a>
# LIGHTGBM: Train 0.742 | Val 0.727 | Test 0.727
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>val_auc</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>0.72692</td></tr><tr><td>test_f1</td><td>0.65703</td></tr><tr><td>test_precision</td><td>0.58662</td></tr><tr><td>test_recall</td><td>0.74664</td></tr><tr><td>train_auc</td><td>0.74242</td></tr><tr><td>val_auc</td><td>0.7268</td></tr><tr><td>val_f1</td><td>0.65686</td></tr><tr><td>val_precision</td><td>0.58731</td></tr><tr><td>val_recall</td><td>0.7451</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hearty-sweep-3</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/q95ai8oh' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/q95ai8oh</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_042638-q95ai8oh/logs</code>
# wandb: Agent Starting Run: ydy75n8j with config:
# wandb: 	learning_rate: 0.027816705873156853
# wandb: 	max_depth: 10
# wandb: 	model_type: lightgbm
# wandb: 	n_estimators: 300
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_042644-ydy75n8j</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ydy75n8j' target="_blank">ethereal-sweep-4</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ydy75n8j' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/ydy75n8j</a>
# LIGHTGBM: Train 0.746 | Val 0.727 | Test 0.727
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>val_auc</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>0.72693</td></tr><tr><td>test_f1</td><td>0.65703</td></tr><tr><td>test_precision</td><td>0.58778</td></tr><tr><td>test_recall</td><td>0.74479</td></tr><tr><td>train_auc</td><td>0.74567</td></tr><tr><td>val_auc</td><td>0.72695</td></tr><tr><td>val_f1</td><td>0.6571</td></tr><tr><td>val_precision</td><td>0.58711</td></tr><tr><td>val_recall</td><td>0.74603</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ethereal-sweep-4</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ydy75n8j' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/ydy75n8j</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_042644-ydy75n8j/logs</code>
# wandb: Agent Starting Run: cvccc5vc with config:
# wandb: 	learning_rate: 0.02170568302558138
# wandb: 	max_depth: 10
# wandb: 	model_type: lightgbm
# wandb: 	n_estimators: 300
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_042649-cvccc5vc</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/cvccc5vc' target="_blank">earnest-sweep-5</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/cvccc5vc' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/cvccc5vc</a>
# LIGHTGBM: Train 0.742 | Val 0.727 | Test 0.727
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>val_auc</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>0.72691</td></tr><tr><td>test_f1</td><td>0.65703</td></tr><tr><td>test_precision</td><td>0.58672</td></tr><tr><td>test_recall</td><td>0.74647</td></tr><tr><td>train_auc</td><td>0.74178</td></tr><tr><td>val_auc</td><td>0.72682</td></tr><tr><td>val_f1</td><td>0.6574</td></tr><tr><td>val_precision</td><td>0.58702</td></tr><tr><td>val_recall</td><td>0.74696</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">earnest-sweep-5</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/cvccc5vc' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/cvccc5vc</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_042649-cvccc5vc/logs</code>
# wandb: Agent Starting Run: oreghm8h with config:
# wandb: 	learning_rate: 0.0249330801723996
# wandb: 	max_depth: 10
# wandb: 	model_type: lightgbm
# wandb: 	n_estimators: 200
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_042655-oreghm8h</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/oreghm8h' target="_blank">rich-sweep-6</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/oreghm8h' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/oreghm8h</a>
# LIGHTGBM: Train 0.738 | Val 0.726 | Test 0.726
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>val_auc</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>0.72649</td></tr><tr><td>test_f1</td><td>0.65608</td></tr><tr><td>test_precision</td><td>0.58506</td></tr><tr><td>test_recall</td><td>0.74673</td></tr><tr><td>train_auc</td><td>0.73772</td></tr><tr><td>val_auc</td><td>0.72646</td></tr><tr><td>val_f1</td><td>0.65918</td></tr><tr><td>val_precision</td><td>0.58876</td></tr><tr><td>val_recall</td><td>0.74873</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">rich-sweep-6</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/oreghm8h' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/oreghm8h</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_042655-oreghm8h/logs</code>
# wandb: Agent Starting Run: j999acmd with config:
# wandb: 	learning_rate: 0.01642347133206622
# wandb: 	max_depth: 10
# wandb: 	model_type: lightgbm
# wandb: 	n_estimators: 300
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_042700-j999acmd</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/j999acmd' target="_blank">balmy-sweep-7</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/j999acmd' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/j999acmd</a>
# LIGHTGBM: Train 0.737 | Val 0.727 | Test 0.727
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>val_auc</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>0.72662</td></tr><tr><td>test_f1</td><td>0.65657</td></tr><tr><td>test_precision</td><td>0.58573</td></tr><tr><td>test_recall</td><td>0.7469</td></tr><tr><td>train_auc</td><td>0.73733</td></tr><tr><td>val_auc</td><td>0.72664</td></tr><tr><td>val_f1</td><td>0.65951</td></tr><tr><td>val_precision</td><td>0.58846</td></tr><tr><td>val_recall</td><td>0.75008</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">balmy-sweep-7</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/j999acmd' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/j999acmd</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_042700-j999acmd/logs</code>
# wandb: Agent Starting Run: 8pd5uch8 with config:
# wandb: 	learning_rate: 0.013231942977409782
# wandb: 	max_depth: 8
# wandb: 	model_type: lightgbm
# wandb: 	n_estimators: 300
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_042706-8pd5uch8</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/8pd5uch8' target="_blank">wild-sweep-8</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/8pd5uch8' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/8pd5uch8</a>
# LIGHTGBM: Train 0.735 | Val 0.726 | Test 0.726
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>val_auc</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>0.72627</td></tr><tr><td>test_f1</td><td>0.65569</td></tr><tr><td>test_precision</td><td>0.58558</td></tr><tr><td>test_recall</td><td>0.74487</td></tr><tr><td>train_auc</td><td>0.73475</td></tr><tr><td>val_auc</td><td>0.72638</td></tr><tr><td>val_f1</td><td>0.65848</td></tr><tr><td>val_precision</td><td>0.58833</td></tr><tr><td>val_recall</td><td>0.74764</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">wild-sweep-8</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/8pd5uch8' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/8pd5uch8</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_042706-8pd5uch8/logs</code>
# wandb: Agent Starting Run: iot48sj5 with config:
# wandb: 	learning_rate: 0.01020713570022642
# wandb: 	max_depth: 8
# wandb: 	model_type: xgboost
# wandb: 	n_estimators: 200
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_042711-iot48sj5</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/iot48sj5' target="_blank">zany-sweep-9</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/iot48sj5' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/iot48sj5</a>
# XGBOOST: Train 0.753 | Val 0.724 | Test 0.724
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>val_auc</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>0.72408</td></tr><tr><td>test_f1</td><td>0.65685</td></tr><tr><td>test_precision</td><td>0.58801</td></tr><tr><td>test_recall</td><td>0.74394</td></tr><tr><td>train_auc</td><td>0.75296</td></tr><tr><td>val_auc</td><td>0.72445</td></tr><tr><td>val_f1</td><td>0.65625</td></tr><tr><td>val_precision</td><td>0.58644</td></tr><tr><td>val_recall</td><td>0.74493</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">zany-sweep-9</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/iot48sj5' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/iot48sj5</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_042711-iot48sj5/logs</code>
# wandb: Agent Starting Run: gf2zbsjl with config:
# wandb: 	learning_rate: 0.17294065810406992
# wandb: 	max_depth: 3
# wandb: 	model_type: lightgbm
# wandb: 	n_estimators: 100
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_042717-gf2zbsjl</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/gf2zbsjl' target="_blank">driven-sweep-10</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/pk7vkeqn</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/gf2zbsjl' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/gf2zbsjl</a>
# LIGHTGBM: Train 0.732 | Val 0.726 | Test 0.726
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁</td></tr><tr><td>val_auc</td><td>▁</td></tr><tr><td>val_f1</td><td>▁</td></tr><tr><td>val_precision</td><td>▁</td></tr><tr><td>val_recall</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>test_auc</td><td>0.72558</td></tr><tr><td>test_f1</td><td>0.65653</td></tr><tr><td>test_precision</td><td>0.58506</td></tr><tr><td>test_recall</td><td>0.74791</td></tr><tr><td>train_auc</td><td>0.73185</td></tr><tr><td>val_auc</td><td>0.72644</td></tr><tr><td>val_f1</td><td>0.65595</td></tr><tr><td>val_precision</td><td>0.58434</td></tr><tr><td>val_recall</td><td>0.74755</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">driven-sweep-10</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/gf2zbsjl' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/gf2zbsjl</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_042717-gf2zbsjl/logs</code>

# %%
run_lstm_sweep(count=20)
# Out:
# ================================================================================
# LSTM SWEEP (20 runs)
# ================================================================================
# Create sweep with ID: iimvxwhr
# Sweep URL: https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr
# wandb: Agent Starting Run: 98jdu8te with config:
# wandb: 	dropout: 0.12084462228588304
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 256
# wandb: 	learning_rate: 0.00625821406522273
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_042928-98jdu8te</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/98jdu8te' target="_blank">crimson-sweep-1</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/98jdu8te' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/98jdu8te</a>
# Epoch 05 | Train 0.669 | Val 0.684
# Early stopping at epoch 9
#
# LSTM: Best Val 0.695 | Test 0.695
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▄▅▅▆▇█</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▅▅▄▄▄▆▆█</td></tr><tr><td>val_auc</td><td>▅█▄▃▄▁▄▇▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>9</td></tr><tr><td>test_auc</td><td>0.69506</td></tr><tr><td>test_f1</td><td>0.58833</td></tr><tr><td>test_precision</td><td>0.59589</td></tr><tr><td>test_recall</td><td>0.58095</td></tr><tr><td>train_auc</td><td>0.68039</td></tr><tr><td>val_auc</td><td>0.68284</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">crimson-sweep-1</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/98jdu8te' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/98jdu8te</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_042928-98jdu8te/logs</code>
# wandb: Agent Starting Run: 8vagytl4 with config:
# wandb: 	dropout: 0.45649425272167377
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 64
# wandb: 	learning_rate: 0.0002866502291968808
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_043247-8vagytl4</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/8vagytl4' target="_blank">curious-sweep-2</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/8vagytl4' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/8vagytl4</a>
# Epoch 05 | Train 0.699 | Val 0.711
# Epoch 10 | Train 0.707 | Val 0.716
# Epoch 15 | Train 0.711 | Val 0.721
# Epoch 20 | Train 0.714 | Val 0.720
# Epoch 25 | Train 0.722 | Val 0.725
# Epoch 30 | Train 0.722 | Val 0.724
#
# LSTM: Best Val 0.725 | Test 0.723
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇████████</td></tr><tr><td>val_auc</td><td>▁▂▄▄▄▅▆▅▅▆▆▅▆▇▇▇▆█▇▇▆▇████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.72317</td></tr><tr><td>test_f1</td><td>0.62699</td></tr><tr><td>test_precision</td><td>0.60998</td></tr><tr><td>test_recall</td><td>0.64496</td></tr><tr><td>train_auc</td><td>0.72227</td></tr><tr><td>val_auc</td><td>0.72419</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">curious-sweep-2</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/8vagytl4' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/8vagytl4</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_043247-8vagytl4/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: locrnfos with config:
# wandb: 	dropout: 0.22360398422890176
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 256
# wandb: 	learning_rate: 0.005824178951534218
# wandb: 	num_layers: 2
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_044019-locrnfos</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/locrnfos' target="_blank">stellar-sweep-3</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/locrnfos' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/locrnfos</a>
# Epoch 05 | Train 0.603 | Val 0.646
# Early stopping at epoch 8
#
# LSTM: Best Val 0.662 | Test 0.662
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▄▅▆▇█</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>█▇▆▃▁▂▂▂</td></tr><tr><td>val_auc</td><td>█▇▂▄▁▃▁▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>8</td></tr><tr><td>test_auc</td><td>0.66171</td></tr><tr><td>test_f1</td><td>0.34348</td></tr><tr><td>test_precision</td><td>0.628</td></tr><tr><td>test_recall</td><td>0.23638</td></tr><tr><td>train_auc</td><td>0.61079</td></tr><tr><td>val_auc</td><td>0.65213</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">stellar-sweep-3</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/locrnfos' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/locrnfos</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_044019-locrnfos/logs</code>
# wandb: Agent Starting Run: eq5fdcpk with config:
# wandb: 	dropout: 0.4261147704479063
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 128
# wandb: 	learning_rate: 0.00023193191555213175
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_044429-eq5fdcpk</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/eq5fdcpk' target="_blank">likely-sweep-4</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/eq5fdcpk' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/eq5fdcpk</a>
# Epoch 05 | Train 0.700 | Val 0.711
# Epoch 10 | Train 0.706 | Val 0.716
# Epoch 15 | Train 0.712 | Val 0.717
# Epoch 20 | Train 0.715 | Val 0.717
# Epoch 25 | Train 0.717 | Val 0.718
# Epoch 30 | Train 0.719 | Val 0.719
#
# LSTM: Best Val 0.722 | Test 0.720
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇███████</td></tr><tr><td>val_auc</td><td>▁▂▃▄▅▅▅▆▅▆▆▆▇▇▇▇▆█▇▇██▇█▇█▆██▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.72014</td></tr><tr><td>test_f1</td><td>0.64012</td></tr><tr><td>test_precision</td><td>0.59769</td></tr><tr><td>test_recall</td><td>0.68905</td></tr><tr><td>train_auc</td><td>0.71932</td></tr><tr><td>val_auc</td><td>0.71938</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">likely-sweep-4</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/eq5fdcpk' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/eq5fdcpk</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_044429-eq5fdcpk/logs</code>
# wandb: Agent Starting Run: 5j2ngf24 with config:
# wandb: 	dropout: 0.4550278346003299
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 128
# wandb: 	learning_rate: 0.00017670394050244416
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_045158-5j2ngf24</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/5j2ngf24' target="_blank">devout-sweep-5</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/5j2ngf24' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/5j2ngf24</a>
# Epoch 05 | Train 0.699 | Val 0.713
# Epoch 10 | Train 0.710 | Val 0.718
# Epoch 15 | Train 0.714 | Val 0.722
# Epoch 20 | Train 0.715 | Val 0.723
# Epoch 25 | Train 0.723 | Val 0.726
# Epoch 30 | Train 0.723 | Val 0.725
#
# LSTM: Best Val 0.726 | Test 0.721
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇██████████</td></tr><tr><td>val_auc</td><td>▁▃▄▄▅▅▆▇▆▆▆▇▇▇▇▇▇▇▇▇██████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.7214</td></tr><tr><td>test_f1</td><td>0.62218</td></tr><tr><td>test_precision</td><td>0.6131</td></tr><tr><td>test_recall</td><td>0.63153</td></tr><tr><td>train_auc</td><td>0.72326</td></tr><tr><td>val_auc</td><td>0.72545</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">devout-sweep-5</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/5j2ngf24' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/5j2ngf24</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_045158-5j2ngf24/logs</code>
# wandb: Agent Starting Run: n4llphko with config:
# wandb: 	dropout: 0.4384132436296485
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 128
# wandb: 	learning_rate: 0.0001056216763600372
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_045931-n4llphko</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/n4llphko' target="_blank">wise-sweep-6</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/n4llphko' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/n4llphko</a>
# Epoch 05 | Train 0.698 | Val 0.710
# Epoch 10 | Train 0.706 | Val 0.715
# Epoch 15 | Train 0.710 | Val 0.718
# Epoch 20 | Train 0.713 | Val 0.720
# Epoch 25 | Train 0.716 | Val 0.721
# Epoch 30 | Train 0.718 | Val 0.721
#
# LSTM: Best Val 0.721 | Test 0.719
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>val_auc</td><td>▁▃▅▅▆▆▆▆▆▇▇▇▇▇▇▇█▇▇████▆██▇▇██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.71909</td></tr><tr><td>test_f1</td><td>0.61758</td></tr><tr><td>test_precision</td><td>0.6112</td></tr><tr><td>test_recall</td><td>0.6241</td></tr><tr><td>train_auc</td><td>0.71816</td></tr><tr><td>val_auc</td><td>0.72115</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">wise-sweep-6</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/n4llphko' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/n4llphko</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_045931-n4llphko/logs</code>
# wandb: Agent Starting Run: idiqam8l with config:
# wandb: 	dropout: 0.49812722902403805
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 64
# wandb: 	learning_rate: 0.00023271290986207773
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_050659-idiqam8l</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/idiqam8l' target="_blank">leafy-sweep-7</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/idiqam8l' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/idiqam8l</a>
# Epoch 05 | Train 0.698 | Val 0.710
# Epoch 10 | Train 0.706 | Val 0.716
# Epoch 15 | Train 0.708 | Val 0.719
# Epoch 20 | Train 0.715 | Val 0.722
# Epoch 25 | Train 0.718 | Val 0.722
# Epoch 30 | Train 0.717 | Val 0.722
#
# LSTM: Best Val 0.723 | Test 0.721
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▅▆▆▆▆▆▇▆▇▇▇▇▇▇▇▇███████████</td></tr><tr><td>val_auc</td><td>▁▃▄▄▅▅▆▅▅▆▇▇▇▇▇▆▇▇▇███████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.72085</td></tr><tr><td>test_f1</td><td>0.61541</td></tr><tr><td>test_precision</td><td>0.61533</td></tr><tr><td>test_recall</td><td>0.61549</td></tr><tr><td>train_auc</td><td>0.7175</td></tr><tr><td>val_auc</td><td>0.7223</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">leafy-sweep-7</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/idiqam8l' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/idiqam8l</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_050659-idiqam8l/logs</code>
# wandb: Agent Starting Run: 97qpnlm2 with config:
# wandb: 	dropout: 0.4931949529772972
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 128
# wandb: 	learning_rate: 0.00038244540326968384
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_051422-97qpnlm2</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/97qpnlm2' target="_blank">breezy-sweep-8</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/97qpnlm2' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/97qpnlm2</a>
# Epoch 05 | Train 0.698 | Val 0.710
# Epoch 10 | Train 0.706 | Val 0.719
# Epoch 15 | Train 0.712 | Val 0.722
# Epoch 20 | Train 0.715 | Val 0.724
# Epoch 25 | Train 0.722 | Val 0.726
# Epoch 30 | Train 0.724 | Val 0.725
#
# LSTM: Best Val 0.726 | Test 0.724
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▃▄▄▅▅▅▅▆▆▆▆▇▆▇▇▇▇▇▇▇▇████████</td></tr><tr><td>val_auc</td><td>▁▂▃▃▄▄▅▆▅▆▆▇▇▇▇▇▇█▇█▇▇████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.72395</td></tr><tr><td>test_f1</td><td>0.6224</td></tr><tr><td>test_precision</td><td>0.61376</td></tr><tr><td>test_recall</td><td>0.63128</td></tr><tr><td>train_auc</td><td>0.7238</td></tr><tr><td>val_auc</td><td>0.72546</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">breezy-sweep-8</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/97qpnlm2' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/97qpnlm2</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_051422-97qpnlm2/logs</code>
# wandb: Agent Starting Run: arp3yukb with config:
# wandb: 	dropout: 0.4946196072051422
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 256
# wandb: 	learning_rate: 0.00022428413065639615
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_052150-arp3yukb</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/arp3yukb' target="_blank">happy-sweep-9</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/arp3yukb' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/arp3yukb</a>
# Epoch 05 | Train 0.695 | Val 0.709
# Epoch 10 | Train 0.706 | Val 0.716
# Epoch 15 | Train 0.711 | Val 0.719
# Epoch 20 | Train 0.720 | Val 0.724
# Epoch 25 | Train 0.722 | Val 0.724
# Epoch 30 | Train 0.723 | Val 0.723
#
# LSTM: Best Val 0.724 | Test 0.720
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███████████</td></tr><tr><td>val_auc</td><td>▁▂▃▄▅▅▅▆▆▆▆▇▆▇▇▆▇▇████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.72022</td></tr><tr><td>test_f1</td><td>0.62239</td></tr><tr><td>test_precision</td><td>0.60733</td></tr><tr><td>test_recall</td><td>0.63821</td></tr><tr><td>train_auc</td><td>0.72316</td></tr><tr><td>val_auc</td><td>0.72343</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">happy-sweep-9</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/arp3yukb' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/arp3yukb</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_052150-arp3yukb/logs</code>
# wandb: Agent Starting Run: ktbrmf7n with config:
# wandb: 	dropout: 0.4874533387093466
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 256
# wandb: 	learning_rate: 0.0002399114988833118
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_053243-ktbrmf7n</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ktbrmf7n' target="_blank">playful-sweep-10</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ktbrmf7n' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/ktbrmf7n</a>
# Epoch 05 | Train 0.697 | Val 0.710
# Epoch 10 | Train 0.708 | Val 0.720
# Epoch 15 | Train 0.712 | Val 0.717
# Epoch 20 | Train 0.722 | Val 0.725
# Epoch 25 | Train 0.724 | Val 0.725
# Early stopping at epoch 27
#
# LSTM: Best Val 0.725 | Test 0.721
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▃▄▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇█████████</td></tr><tr><td>val_auc</td><td>▁▂▃▃▅▅▅▆▆▇▇▇▇▇▆▇███████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>27</td></tr><tr><td>test_auc</td><td>0.72138</td></tr><tr><td>test_f1</td><td>0.62389</td></tr><tr><td>test_precision</td><td>0.61184</td></tr><tr><td>test_recall</td><td>0.63643</td></tr><tr><td>train_auc</td><td>0.72537</td></tr><tr><td>val_auc</td><td>0.7248</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">playful-sweep-10</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ktbrmf7n' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/ktbrmf7n</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_053243-ktbrmf7n/logs</code>
# wandb: Agent Starting Run: hvw2ou9y with config:
# wandb: 	dropout: 0.47363657006906634
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 256
# wandb: 	learning_rate: 0.00025225313555890836
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_054229-hvw2ou9y</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/hvw2ou9y' target="_blank">copper-sweep-11</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/hvw2ou9y' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/hvw2ou9y</a>
# Epoch 05 | Train 0.696 | Val 0.710
# Epoch 10 | Train 0.710 | Val 0.721
# Epoch 15 | Train 0.715 | Val 0.722
# Epoch 20 | Train 0.723 | Val 0.727
# Epoch 25 | Train 0.725 | Val 0.727
# Epoch 30 | Train 0.726 | Val 0.727
#
# LSTM: Best Val 0.728 | Test 0.722
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▃▄▄▄▅▆▆▆▆▆▆▆▇▇▇▇▇████████████</td></tr><tr><td>val_auc</td><td>▁▃▃▄▄▅▅▆▆▇▇▇▆▇▇███████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.72228</td></tr><tr><td>test_f1</td><td>0.62843</td></tr><tr><td>test_precision</td><td>0.60859</td></tr><tr><td>test_recall</td><td>0.64961</td></tr><tr><td>train_auc</td><td>0.72589</td></tr><tr><td>val_auc</td><td>0.72741</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">copper-sweep-11</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/hvw2ou9y' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/hvw2ou9y</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_054229-hvw2ou9y/logs</code>
# wandb: Agent Starting Run: 5q6r5oz2 with config:
# wandb: 	dropout: 0.44009823993123254
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 256
# wandb: 	learning_rate: 0.00015007424842346278
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_055327-5q6r5oz2</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/5q6r5oz2' target="_blank">hopeful-sweep-12</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/5q6r5oz2' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/5q6r5oz2</a>
# Epoch 05 | Train 0.698 | Val 0.709
# Epoch 10 | Train 0.707 | Val 0.716
# Epoch 15 | Train 0.717 | Val 0.722
# Epoch 20 | Train 0.718 | Val 0.722
# Epoch 25 | Train 0.718 | Val 0.723
# Epoch 30 | Train 0.720 | Val 0.723
#
# LSTM: Best Val 0.723 | Test 0.721
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▄▅▅▅▆▆▆▆▆▆▇▇▇▇██████████████</td></tr><tr><td>val_auc</td><td>▁▃▃▄▄▅▆▆▆▆▆▆▇█████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.72057</td></tr><tr><td>test_f1</td><td>0.61303</td></tr><tr><td>test_precision</td><td>0.6167</td></tr><tr><td>test_recall</td><td>0.60941</td></tr><tr><td>train_auc</td><td>0.72031</td></tr><tr><td>val_auc</td><td>0.72307</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hopeful-sweep-12</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/5q6r5oz2' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/5q6r5oz2</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_055327-5q6r5oz2/logs</code>
# wandb: Agent Starting Run: a0emvikv with config:
# wandb: 	dropout: 0.454876769433553
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 256
# wandb: 	learning_rate: 0.0005525000085965897
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_060420-a0emvikv</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/a0emvikv' target="_blank">dainty-sweep-13</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/a0emvikv' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/a0emvikv</a>
# Epoch 05 | Train 0.693 | Val 0.706
# Epoch 10 | Train 0.703 | Val 0.713
# Epoch 15 | Train 0.707 | Val 0.716
# Epoch 20 | Train 0.710 | Val 0.720
# Epoch 25 | Train 0.718 | Val 0.722
# Epoch 30 | Train 0.722 | Val 0.722
#
# LSTM: Best Val 0.722 | Test 0.719
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▃▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇█████</td></tr><tr><td>val_auc</td><td>▁▂▃▃▄▄▄▅▅▆▅▆▆▆▆▇▇▆▇█▇▇▇▆██████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.71948</td></tr><tr><td>test_f1</td><td>0.62912</td></tr><tr><td>test_precision</td><td>0.60512</td></tr><tr><td>test_recall</td><td>0.6551</td></tr><tr><td>train_auc</td><td>0.72212</td></tr><tr><td>val_auc</td><td>0.72212</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dainty-sweep-13</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/a0emvikv' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/a0emvikv</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_060420-a0emvikv/logs</code>
# wandb: Agent Starting Run: ajog9q77 with config:
# wandb: 	dropout: 0.481819610195382
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 64
# wandb: 	learning_rate: 0.001224926034035904
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_061544-ajog9q77</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ajog9q77' target="_blank">lucky-sweep-14</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ajog9q77' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/ajog9q77</a>
# Epoch 05 | Train 0.689 | Val 0.703
# Epoch 10 | Train 0.692 | Val 0.706
# Epoch 15 | Train 0.696 | Val 0.708
# Epoch 20 | Train 0.699 | Val 0.712
# Epoch 25 | Train 0.707 | Val 0.715
# Epoch 30 | Train 0.710 | Val 0.716
#
# LSTM: Best Val 0.717 | Test 0.715
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇█████</td></tr><tr><td>val_auc</td><td>▁▂▂▂▃▃▃▄▃▄▄▄▄▅▅▆▅▅▆▆▅▆▆▅▇█████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.71521</td></tr><tr><td>test_f1</td><td>0.62762</td></tr><tr><td>test_precision</td><td>0.59553</td></tr><tr><td>test_recall</td><td>0.66337</td></tr><tr><td>train_auc</td><td>0.70957</td></tr><tr><td>val_auc</td><td>0.71623</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">lucky-sweep-14</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ajog9q77' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/ajog9q77</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_061544-ajog9q77/logs</code>
# wandb: Agent Starting Run: wxdwszag with config:
# wandb: 	dropout: 0.49467504237251
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 128
# wandb: 	learning_rate: 0.00021518651883907695
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_062237-wxdwszag</code>
# ...
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/tc3bsbaz' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/tc3bsbaz</a>
# Epoch 05 | Train 0.700 | Val 0.711
# Epoch 10 | Train 0.709 | Val 0.717
# Epoch 15 | Train 0.713 | Val 0.720
# Epoch 20 | Train 0.716 | Val 0.723
# Epoch 25 | Train 0.717 | Val 0.725
# Epoch 30 | Train 0.722 | Val 0.725
#
# LSTM: Best Val 0.725 | Test 0.722
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇████████</td></tr><tr><td>val_auc</td><td>▁▃▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇████▇████▇███</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.72215</td></tr><tr><td>test_f1</td><td>0.62042</td></tr><tr><td>test_precision</td><td>0.61119</td></tr><tr><td>test_recall</td><td>0.62993</td></tr><tr><td>train_auc</td><td>0.72186</td></tr><tr><td>val_auc</td><td>0.7246</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">super-sweep-16</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/tc3bsbaz' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/tc3bsbaz</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_062930-tc3bsbaz/logs</code>
# wandb: Agent Starting Run: htgq8l79 with config:
# wandb: 	dropout: 0.3269297155329037
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 64
# wandb: 	learning_rate: 0.0001649805209692253
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_063619-htgq8l79</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/htgq8l79' target="_blank">classic-sweep-17</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/htgq8l79' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/htgq8l79</a>
# Epoch 05 | Train 0.702 | Val 0.713
# Epoch 10 | Train 0.711 | Val 0.715
# Epoch 15 | Train 0.715 | Val 0.721
# Epoch 20 | Train 0.718 | Val 0.723
# Epoch 25 | Train 0.720 | Val 0.723
# Epoch 30 | Train 0.725 | Val 0.725
#
# LSTM: Best Val 0.725 | Test 0.722
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████</td></tr><tr><td>val_auc</td><td>▁▃▃▄▅▆▆▆▆▆▇▇▇▇▇█▇█▇██▇█▇██████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.72244</td></tr><tr><td>test_f1</td><td>0.62649</td></tr><tr><td>test_precision</td><td>0.60875</td></tr><tr><td>test_recall</td><td>0.6453</td></tr><tr><td>train_auc</td><td>0.72507</td></tr><tr><td>val_auc</td><td>0.72468</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">classic-sweep-17</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/htgq8l79' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/htgq8l79</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_063619-htgq8l79/logs</code>
# wandb: Agent Starting Run: cos321a7 with config:
# wandb: 	dropout: 0.19637163523311707
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 64
# wandb: 	learning_rate: 0.00021851332098679944
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_064338-cos321a7</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/cos321a7' target="_blank">daily-sweep-18</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/cos321a7' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/cos321a7</a>
# Epoch 05 | Train 0.706 | Val 0.713
# Epoch 10 | Train 0.712 | Val 0.712
# Epoch 15 | Train 0.716 | Val 0.718
# Epoch 20 | Train 0.723 | Val 0.723
# Epoch 25 | Train 0.724 | Val 0.723
# Epoch 30 | Train 0.725 | Val 0.723
#
# LSTM: Best Val 0.723 | Test 0.722
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▅▆▆▆▆▆▆▆▇▇▇▇███████████████</td></tr><tr><td>val_auc</td><td>▁▄▅▅▆▅▆▆▆▅▇▇▇▇▇███████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.72173</td></tr><tr><td>test_f1</td><td>0.61626</td></tr><tr><td>test_precision</td><td>0.61276</td></tr><tr><td>test_recall</td><td>0.6198</td></tr><tr><td>train_auc</td><td>0.72515</td></tr><tr><td>val_auc</td><td>0.72305</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">daily-sweep-18</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/cos321a7' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/cos321a7</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_064338-cos321a7/logs</code>
# wandb: Agent Starting Run: fna42p22 with config:
# wandb: 	dropout: 0.3411741876919513
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 64
# wandb: 	learning_rate: 0.00010189930834192588
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_064955-fna42p22</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/fna42p22' target="_blank">royal-sweep-19</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/fna42p22' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/fna42p22</a>
# Epoch 05 | Train 0.703 | Val 0.708
# Epoch 10 | Train 0.709 | Val 0.717
# Epoch 15 | Train 0.714 | Val 0.719
# Epoch 20 | Train 0.715 | Val 0.723
# Epoch 25 | Train 0.721 | Val 0.725
# Epoch 30 | Train 0.723 | Val 0.725
#
# LSTM: Best Val 0.725 | Test 0.723
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████</td></tr><tr><td>val_auc</td><td>▁▃▄▅▅▆▆▆▆▇▇▆▇▇▇▇▇▇▇███▇███████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.72273</td></tr><tr><td>test_f1</td><td>0.62731</td></tr><tr><td>test_precision</td><td>0.60879</td></tr><tr><td>test_recall</td><td>0.64699</td></tr><tr><td>train_auc</td><td>0.72251</td></tr><tr><td>val_auc</td><td>0.72505</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">royal-sweep-19</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/fna42p22' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/fna42p22</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_064955-fna42p22/logs</code>
# wandb: Agent Starting Run: 6voipaw6 with config:
# wandb: 	dropout: 0.30331091665339277
# wandb: 	epochs: 30
# wandb: 	hidden_dim: 64
# wandb: 	learning_rate: 0.00011005547571994892
# wandb: 	num_layers: 1
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_065618-6voipaw6</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/6voipaw6' target="_blank">peachy-sweep-20</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/iimvxwhr</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/6voipaw6' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/6voipaw6</a>
# Epoch 05 | Train 0.702 | Val 0.711
# Epoch 10 | Train 0.710 | Val 0.715
# Epoch 15 | Train 0.713 | Val 0.719
# Epoch 20 | Train 0.716 | Val 0.721
# Epoch 25 | Train 0.721 | Val 0.723
# Epoch 30 | Train 0.722 | Val 0.723
#
# LSTM: Best Val 0.723 | Test 0.721
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>val_auc</td><td>▁▄▅▆▆▆▆▆▆▇▇▇▇▇▇▇█▇████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>30</td></tr><tr><td>test_auc</td><td>0.72099</td></tr><tr><td>test_f1</td><td>0.61521</td></tr><tr><td>test_precision</td><td>0.61384</td></tr><tr><td>test_recall</td><td>0.61659</td></tr><tr><td>train_auc</td><td>0.72186</td></tr><tr><td>val_auc</td><td>0.72331</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">peachy-sweep-20</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/6voipaw6' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/6voipaw6</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_065618-6voipaw6/logs</code>

# %%
run_gnn_sweep(count=15)
# Out:
# ================================================================================
# GNN SWEEP (15 runs)
# ================================================================================
# Create sweep with ID: fcwt7ups
# Sweep URL: https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups
# wandb: Agent Starting Run: 5pnb7pmq with config:
# wandb: 	dropout: 0.4843811920524954
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 256
# wandb: 	learning_rate: 0.08226483188419124
# wandb: 	num_layers: 2
# wandb: 	weight_decay: 1.771897664335087e-05
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070721-5pnb7pmq</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/5pnb7pmq' target="_blank">colorful-sweep-1</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/5pnb7pmq' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/5pnb7pmq</a>
# Epoch 010 | Train 0.500 | Val 0.500
# Early stopping at epoch 16
#
# GNN: Best Val 0.570 | Test 0.565
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▆▆▇▇██</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>█▁▁▆▄▅▅▅▅▅▅▅▅▅▅▅</td></tr><tr><td>val_auc</td><td>█▁▁▆▄▅▅▅▅▅▅▅▅▅▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>16</td></tr><tr><td>test_auc</td><td>0.5651</td></tr><tr><td>test_f1</td><td>0</td></tr><tr><td>test_precision</td><td>0</td></tr><tr><td>test_recall</td><td>0</td></tr><tr><td>train_auc</td><td>0.5</td></tr><tr><td>val_auc</td><td>0.5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">colorful-sweep-1</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/5pnb7pmq' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/5pnb7pmq</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070721-5pnb7pmq/logs</code>
# wandb: Agent Starting Run: x6i1dvr0 with config:
# wandb: 	dropout: 0.11799151259717124
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 256
# wandb: 	learning_rate: 0.007311143920361205
# wandb: 	num_layers: 1
# wandb: 	weight_decay: 0.0009427576617795124
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070727-x6i1dvr0</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/x6i1dvr0' target="_blank">brisk-sweep-2</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/x6i1dvr0' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/x6i1dvr0</a>
# Epoch 010 | Train 0.710 | Val 0.711
# Epoch 020 | Train 0.711 | Val 0.713
# Epoch 030 | Train 0.712 | Val 0.713
# Epoch 040 | Train 0.712 | Val 0.713
# Epoch 050 | Train 0.713 | Val 0.714
# Epoch 060 | Train 0.713 | Val 0.714
# Epoch 070 | Train 0.713 | Val 0.715
# Epoch 080 | Train 0.714 | Val 0.715
# Epoch 090 | Train 0.714 | Val 0.715
# Epoch 100 | Train 0.715 | Val 0.716
#
# GNN: Best Val 0.716 | Test 0.716
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████</td></tr><tr><td>val_auc</td><td>▁▄▄▅▅▆▆▆▆▆▆▆▆▆▇▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71609</td></tr><tr><td>test_f1</td><td>0.62441</td></tr><tr><td>test_precision</td><td>0.59958</td></tr><tr><td>test_recall</td><td>0.65138</td></tr><tr><td>train_auc</td><td>0.71495</td></tr><tr><td>val_auc</td><td>0.71621</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">brisk-sweep-2</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/x6i1dvr0' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/x6i1dvr0</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070727-x6i1dvr0/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: ztv3cclq with config:
# wandb: 	dropout: 0.19494480746883555
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 64
# wandb: 	learning_rate: 0.004001962282335422
# wandb: 	num_layers: 2
# wandb: 	weight_decay: 9.309245676206268e-05
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070742-ztv3cclq</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ztv3cclq' target="_blank">sparkling-sweep-3</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ztv3cclq' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/ztv3cclq</a>
# Epoch 010 | Train 0.703 | Val 0.706
# Epoch 020 | Train 0.709 | Val 0.711
# Epoch 030 | Train 0.711 | Val 0.712
# Epoch 040 | Train 0.713 | Val 0.713
# Epoch 050 | Train 0.714 | Val 0.714
# Epoch 060 | Train 0.716 | Val 0.715
# Epoch 070 | Train 0.717 | Val 0.716
# Epoch 080 | Train 0.718 | Val 0.716
# Epoch 090 | Train 0.719 | Val 0.717
# Epoch 100 | Train 0.721 | Val 0.718
#
# GNN: Best Val 0.718 | Test 0.718
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▃▄▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>val_auc</td><td>▁▃▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71775</td></tr><tr><td>test_f1</td><td>0.62677</td></tr><tr><td>test_precision</td><td>0.5998</td></tr><tr><td>test_recall</td><td>0.65628</td></tr><tr><td>train_auc</td><td>0.72065</td></tr><tr><td>val_auc</td><td>0.7175</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sparkling-sweep-3</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ztv3cclq' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/ztv3cclq</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070742-ztv3cclq/logs</code>
# wandb: Agent Starting Run: duf60613 with config:
# wandb: 	dropout: 0.13717923923830294
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 256
# wandb: 	learning_rate: 0.006546782268997945
# wandb: 	num_layers: 2
# wandb: 	weight_decay: 0.0004011555455683367
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070748-duf60613</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/duf60613' target="_blank">solar-sweep-4</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/duf60613' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/duf60613</a>
# Epoch 010 | Train 0.707 | Val 0.710
# Epoch 020 | Train 0.710 | Val 0.712
# Epoch 030 | Train 0.712 | Val 0.714
# Epoch 040 | Train 0.714 | Val 0.715
# Epoch 050 | Train 0.716 | Val 0.716
# Epoch 060 | Train 0.718 | Val 0.717
# Epoch 070 | Train 0.719 | Val 0.718
# Epoch 080 | Train 0.717 | Val 0.716
# Early stopping at epoch 82
#
# GNN: Best Val 0.718 | Test 0.718
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇█████</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████</td></tr><tr><td>val_auc</td><td>▁▂▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇██████▇███▇▇▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>82</td></tr><tr><td>test_auc</td><td>0.7184</td></tr><tr><td>test_f1</td><td>0.63599</td></tr><tr><td>test_precision</td><td>0.59779</td></tr><tr><td>test_recall</td><td>0.67942</td></tr><tr><td>train_auc</td><td>0.71728</td></tr><tr><td>val_auc</td><td>0.71674</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">solar-sweep-4</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/duf60613' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/duf60613</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070748-duf60613/logs</code>
# wandb: Agent Starting Run: lnloyzmy with config:
# wandb: 	dropout: 0.1570629431840161
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 64
# wandb: 	learning_rate: 0.00226584851421877
# wandb: 	num_layers: 2
# wandb: 	weight_decay: 0.0008459715560421039
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070759-lnloyzmy</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/lnloyzmy' target="_blank">true-sweep-5</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/lnloyzmy' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/lnloyzmy</a>
# Epoch 010 | Train 0.696 | Val 0.699
# Epoch 020 | Train 0.705 | Val 0.708
# Epoch 030 | Train 0.708 | Val 0.710
# Epoch 040 | Train 0.709 | Val 0.711
# Epoch 050 | Train 0.710 | Val 0.712
# Epoch 060 | Train 0.711 | Val 0.713
# Epoch 070 | Train 0.712 | Val 0.713
# Epoch 080 | Train 0.713 | Val 0.714
# Epoch 090 | Train 0.714 | Val 0.715
# Epoch 100 | Train 0.715 | Val 0.715
#
# GNN: Best Val 0.715 | Test 0.715
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▅▆▇▇▇▇▇▇▇██████████████████████████████</td></tr><tr><td>val_auc</td><td>▁▃▄▅▆▇▇▇▇▇▇█████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71527</td></tr><tr><td>test_f1</td><td>0.62855</td></tr><tr><td>test_precision</td><td>0.59355</td></tr><tr><td>test_recall</td><td>0.66793</td></tr><tr><td>train_auc</td><td>0.71507</td></tr><tr><td>val_auc</td><td>0.71516</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">true-sweep-5</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/lnloyzmy' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/lnloyzmy</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070759-lnloyzmy/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: wkej5wtd with config:
# wandb: 	dropout: 0.10962832527246628
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 256
# wandb: 	learning_rate: 0.001344752301550413
# wandb: 	num_layers: 2
# wandb: 	weight_decay: 0.00013889881604315507
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070814-wkej5wtd</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/wkej5wtd' target="_blank">polar-sweep-6</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/wkej5wtd' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/wkej5wtd</a>
# Epoch 010 | Train 0.706 | Val 0.709
# Epoch 020 | Train 0.709 | Val 0.710
# Epoch 030 | Train 0.711 | Val 0.712
# Epoch 040 | Train 0.713 | Val 0.714
# Epoch 050 | Train 0.714 | Val 0.714
# Epoch 060 | Train 0.716 | Val 0.715
# Epoch 070 | Train 0.717 | Val 0.716
# Epoch 080 | Train 0.718 | Val 0.716
# Epoch 090 | Train 0.720 | Val 0.717
# Epoch 100 | Train 0.721 | Val 0.717
#
# GNN: Best Val 0.717 | Test 0.717
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇█</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████</td></tr><tr><td>val_auc</td><td>▁▃▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71731</td></tr><tr><td>test_f1</td><td>0.62871</td></tr><tr><td>test_precision</td><td>0.59735</td></tr><tr><td>test_recall</td><td>0.66354</td></tr><tr><td>train_auc</td><td>0.7214</td></tr><tr><td>val_auc</td><td>0.71706</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">polar-sweep-6</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/wkej5wtd' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/wkej5wtd</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070814-wkej5wtd/logs</code>
# wandb: Agent Starting Run: gifricfe with config:
# wandb: 	dropout: 0.12518518585298177
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 128
# wandb: 	learning_rate: 0.0010731126385724412
# wandb: 	num_layers: 1
# wandb: 	weight_decay: 0.00039498953283907977
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070825-gifricfe</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/gifricfe' target="_blank">good-sweep-7</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/gifricfe' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/gifricfe</a>
# Epoch 010 | Train 0.702 | Val 0.704
# Epoch 020 | Train 0.706 | Val 0.709
# Epoch 030 | Train 0.709 | Val 0.711
# Epoch 040 | Train 0.711 | Val 0.712
# Epoch 050 | Train 0.712 | Val 0.713
# Epoch 060 | Train 0.712 | Val 0.713
# Epoch 070 | Train 0.713 | Val 0.714
# Epoch 080 | Train 0.713 | Val 0.714
# Epoch 090 | Train 0.714 | Val 0.714
# Epoch 100 | Train 0.714 | Val 0.715
#
# GNN: Best Val 0.715 | Test 0.715
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇███████████████</td></tr><tr><td>val_auc</td><td>▁▁▂▂▃▃▄▅▅▅▆▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71533</td></tr><tr><td>test_f1</td><td>0.63115</td></tr><tr><td>test_precision</td><td>0.59394</td></tr><tr><td>test_recall</td><td>0.67334</td></tr><tr><td>train_auc</td><td>0.71431</td></tr><tr><td>val_auc</td><td>0.71492</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">good-sweep-7</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/gifricfe' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/gifricfe</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070825-gifricfe/logs</code>
# wandb: Agent Starting Run: 4k63yhvc with config:
# wandb: 	dropout: 0.10371770188508256
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 64
# wandb: 	learning_rate: 0.0015499013402832692
# wandb: 	num_layers: 3
# wandb: 	weight_decay: 7.204794299136697e-05
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070830-4k63yhvc</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/4k63yhvc' target="_blank">electric-sweep-8</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/4k63yhvc' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/4k63yhvc</a>
# Epoch 010 | Train 0.684 | Val 0.683
# Epoch 020 | Train 0.700 | Val 0.704
# Epoch 030 | Train 0.707 | Val 0.709
# Epoch 040 | Train 0.709 | Val 0.710
# Epoch 050 | Train 0.710 | Val 0.711
# Epoch 060 | Train 0.712 | Val 0.712
# Epoch 070 | Train 0.713 | Val 0.713
# Epoch 080 | Train 0.714 | Val 0.713
# Epoch 090 | Train 0.716 | Val 0.714
# Epoch 100 | Train 0.717 | Val 0.715
#
# GNN: Best Val 0.715 | Test 0.715
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▇▇▇▇▇█████████████████████████████████</td></tr><tr><td>val_auc</td><td>▁▅▆▇▇▇▇█████████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71488</td></tr><tr><td>test_f1</td><td>0.62851</td></tr><tr><td>test_precision</td><td>0.59618</td></tr><tr><td>test_recall</td><td>0.66456</td></tr><tr><td>train_auc</td><td>0.71726</td></tr><tr><td>val_auc</td><td>0.71497</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">electric-sweep-8</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/4k63yhvc' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/4k63yhvc</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070830-4k63yhvc/logs</code>
# wandb: Agent Starting Run: o5lrqyy6 with config:
# wandb: 	dropout: 0.10832396609093488
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 64
# wandb: 	learning_rate: 0.0017226015166074
# wandb: 	num_layers: 1
# wandb: 	weight_decay: 9.798660229217594e-05
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070841-o5lrqyy6</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/o5lrqyy6' target="_blank">feasible-sweep-9</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/o5lrqyy6' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/o5lrqyy6</a>
# Epoch 010 | Train 0.699 | Val 0.702
# Epoch 020 | Train 0.705 | Val 0.707
# Epoch 030 | Train 0.709 | Val 0.710
# Epoch 040 | Train 0.711 | Val 0.712
# Epoch 050 | Train 0.712 | Val 0.712
# Epoch 060 | Train 0.712 | Val 0.713
# Epoch 070 | Train 0.713 | Val 0.714
# Epoch 080 | Train 0.714 | Val 0.715
# Epoch 090 | Train 0.715 | Val 0.715
# Epoch 100 | Train 0.716 | Val 0.716
#
# GNN: Best Val 0.716 | Test 0.716
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▃▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▇▇▇▇▇█████</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████</td></tr><tr><td>val_auc</td><td>▁▃▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71627</td></tr><tr><td>test_f1</td><td>0.63109</td></tr><tr><td>test_precision</td><td>0.59589</td></tr><tr><td>test_recall</td><td>0.67072</td></tr><tr><td>train_auc</td><td>0.7162</td></tr><tr><td>val_auc</td><td>0.71613</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">feasible-sweep-9</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/o5lrqyy6' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/o5lrqyy6</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070841-o5lrqyy6/logs</code>
# wandb: Agent Starting Run: ri7xfq5y with config:
# wandb: 	dropout: 0.10822424951891364
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 256
# wandb: 	learning_rate: 0.004392397883021294
# wandb: 	num_layers: 3
# wandb: 	weight_decay: 0.0009879969622336652
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070847-ri7xfq5y</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ri7xfq5y' target="_blank">playful-sweep-10</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ri7xfq5y' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/ri7xfq5y</a>
# Epoch 010 | Train 0.701 | Val 0.705
# Epoch 020 | Train 0.709 | Val 0.710
# Epoch 030 | Train 0.712 | Val 0.713
# Epoch 040 | Train 0.714 | Val 0.714
# Epoch 050 | Train 0.715 | Val 0.715
# Epoch 060 | Train 0.717 | Val 0.716
# Epoch 070 | Train 0.719 | Val 0.717
# Epoch 080 | Train 0.721 | Val 0.719
# Epoch 090 | Train 0.723 | Val 0.719
# Epoch 100 | Train 0.724 | Val 0.719
#
# GNN: Best Val 0.719 | Test 0.719
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▅▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇██████████████████</td></tr><tr><td>val_auc</td><td>▁▆▆▇▇▇▇▇▇▇▇▇████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71898</td></tr><tr><td>test_f1</td><td>0.64306</td></tr><tr><td>test_precision</td><td>0.59303</td></tr><tr><td>test_recall</td><td>0.70231</td></tr><tr><td>train_auc</td><td>0.72387</td></tr><tr><td>val_auc</td><td>0.71913</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">playful-sweep-10</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/ri7xfq5y' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/ri7xfq5y</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070847-ri7xfq5y/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: jt3lezmu with config:
# wandb: 	dropout: 0.10417018878556408
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 64
# wandb: 	learning_rate: 0.0035686978572022085
# wandb: 	num_layers: 3
# wandb: 	weight_decay: 0.00023575176261672728
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070907-jt3lezmu</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/jt3lezmu' target="_blank">decent-sweep-11</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/jt3lezmu' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/jt3lezmu</a>
# Epoch 010 | Train 0.696 | Val 0.699
# Epoch 020 | Train 0.706 | Val 0.707
# Epoch 030 | Train 0.709 | Val 0.710
# Epoch 040 | Train 0.711 | Val 0.712
# Epoch 050 | Train 0.713 | Val 0.713
# Epoch 060 | Train 0.715 | Val 0.714
# Epoch 070 | Train 0.717 | Val 0.715
# Epoch 080 | Train 0.719 | Val 0.716
# Epoch 090 | Train 0.720 | Val 0.717
# Epoch 100 | Train 0.722 | Val 0.718
#
# GNN: Best Val 0.718 | Test 0.718
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇████</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▃▄▅▆▇▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████████</td></tr><tr><td>val_auc</td><td>▁▆▇▇▇▆▆▇▇▇▇▇▇▇██████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71785</td></tr><tr><td>test_f1</td><td>0.61994</td></tr><tr><td>test_precision</td><td>0.60704</td></tr><tr><td>test_recall</td><td>0.63339</td></tr><tr><td>train_auc</td><td>0.72247</td></tr><tr><td>val_auc</td><td>0.71794</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">decent-sweep-11</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/jt3lezmu' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/jt3lezmu</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070907-jt3lezmu/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: e1xtfyst with config:
# wandb: 	dropout: 0.12387644138685153
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 64
# wandb: 	learning_rate: 0.04124026764458524
# wandb: 	num_layers: 1
# wandb: 	weight_decay: 0.0008712853528756047
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070923-e1xtfyst</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/e1xtfyst' target="_blank">smooth-sweep-12</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/e1xtfyst' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/e1xtfyst</a>
# Epoch 010 | Train 0.709 | Val 0.711
# Epoch 020 | Train 0.709 | Val 0.711
# Epoch 030 | Train 0.710 | Val 0.712
# Epoch 040 | Train 0.711 | Val 0.713
# Epoch 050 | Train 0.712 | Val 0.713
# Epoch 060 | Train 0.712 | Val 0.714
# Epoch 070 | Train 0.713 | Val 0.714
# Epoch 080 | Train 0.713 | Val 0.714
# Epoch 090 | Train 0.713 | Val 0.714
# Epoch 100 | Train 0.713 | Val 0.714
#
# GNN: Best Val 0.714 | Test 0.714
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇█</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▄▄▁▅▅▇▇▇▇▇▇▇▇▇██████████████████████████</td></tr><tr><td>val_auc</td><td>▁▃▅▆▅▇▇▆▇▇▇▇▇▇▇▇▇▇▇▇█▇█▇████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71394</td></tr><tr><td>test_f1</td><td>0.62619</td></tr><tr><td>test_precision</td><td>0.59513</td></tr><tr><td>test_recall</td><td>0.66067</td></tr><tr><td>train_auc</td><td>0.71297</td></tr><tr><td>val_auc</td><td>0.71412</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">smooth-sweep-12</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/e1xtfyst' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/e1xtfyst</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070923-e1xtfyst/logs</code>
# wandb: Agent Starting Run: hatp4q3g with config:
# wandb: 	dropout: 0.11175630077622097
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 64
# wandb: 	learning_rate: 0.0063735946967214225
# wandb: 	num_layers: 2
# wandb: 	weight_decay: 0.0001874818581963174
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070928-hatp4q3g</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/hatp4q3g' target="_blank">hopeful-sweep-13</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/hatp4q3g' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/hatp4q3g</a>
# Epoch 010 | Train 0.707 | Val 0.707
# Epoch 020 | Train 0.711 | Val 0.712
# Epoch 030 | Train 0.713 | Val 0.713
# Epoch 040 | Train 0.714 | Val 0.714
# Epoch 050 | Train 0.716 | Val 0.715
# Epoch 060 | Train 0.717 | Val 0.716
# Epoch 070 | Train 0.719 | Val 0.717
# Epoch 080 | Train 0.721 | Val 0.718
# Epoch 090 | Train 0.723 | Val 0.718
# Epoch 100 | Train 0.724 | Val 0.718
#
# GNN: Best Val 0.719 | Test 0.719
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▄▅▅▅▅▅▅▅▅▅▅▅▆▆▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇█████████</td></tr><tr><td>val_auc</td><td>▁▂▂▂▂▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇█████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71902</td></tr><tr><td>test_f1</td><td>0.63721</td></tr><tr><td>test_precision</td><td>0.59565</td></tr><tr><td>test_recall</td><td>0.68499</td></tr><tr><td>train_auc</td><td>0.72391</td></tr><tr><td>val_auc</td><td>0.71848</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">hopeful-sweep-13</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/hatp4q3g' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/hatp4q3g</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070928-hatp4q3g/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: l9624yvi with config:
# wandb: 	dropout: 0.10448917798205531
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 64
# wandb: 	learning_rate: 0.02102033490344793
# wandb: 	num_layers: 3
# wandb: 	weight_decay: 0.0005506940860557141
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070944-l9624yvi</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/l9624yvi' target="_blank">dulcet-sweep-14</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/l9624yvi' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/l9624yvi</a>
# Epoch 010 | Train 0.684 | Val 0.689
# Epoch 020 | Train 0.704 | Val 0.703
# Epoch 030 | Train 0.711 | Val 0.712
# Epoch 040 | Train 0.713 | Val 0.713
# Epoch 050 | Train 0.715 | Val 0.714
# Epoch 060 | Train 0.717 | Val 0.715
# Epoch 070 | Train 0.719 | Val 0.717
# Epoch 080 | Train 0.722 | Val 0.717
# Epoch 090 | Train 0.723 | Val 0.719
# Epoch 100 | Train 0.725 | Val 0.719
#
# GNN: Best Val 0.719 | Test 0.719
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▃▁▇▇▇███████████████████████████████████</td></tr><tr><td>val_auc</td><td>▄▁▁▇▇███████████████████████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71877</td></tr><tr><td>test_f1</td><td>0.6249</td></tr><tr><td>test_precision</td><td>0.60471</td></tr><tr><td>test_recall</td><td>0.64648</td></tr><tr><td>train_auc</td><td>0.72481</td></tr><tr><td>val_auc</td><td>0.71929</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">dulcet-sweep-14</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/l9624yvi' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/l9624yvi</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070944-l9624yvi/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: jhk3pggu with config:
# wandb: 	dropout: 0.1223538818335972
# wandb: 	epochs: 100
# wandb: 	hidden_channels: 64
# wandb: 	learning_rate: 0.01872072280531123
# wandb: 	num_layers: 3
# wandb: 	weight_decay: 0.0006491273015811683
# Ignoring project 'churn-prediction' when running a sweep.
# Tracking run with wandb version 0.22.2
# Run data is saved locally in <code>/content/wandb/run-20251217_070959-jhk3pggu</code>
# Syncing run <strong><a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/jhk3pggu' target="_blank">wandering-sweep-15</a></strong> to <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View project at <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a>
#  View sweep at <a href='https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/sweeps/fcwt7ups</a>
#  View run at <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/jhk3pggu' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/jhk3pggu</a>
# Epoch 010 | Train 0.702 | Val 0.705
# Epoch 020 | Train 0.710 | Val 0.712
# Epoch 030 | Train 0.713 | Val 0.713
# Epoch 040 | Train 0.715 | Val 0.715
# Epoch 050 | Train 0.717 | Val 0.716
# Epoch 060 | Train 0.719 | Val 0.717
# Epoch 070 | Train 0.721 | Val 0.718
# Epoch 080 | Train 0.722 | Val 0.719
# Epoch 090 | Train 0.725 | Val 0.720
# Epoch 100 | Train 0.716 | Val 0.716
#
# GNN: Best Val 0.720 | Test 0.719
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>test_auc</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>train_auc</td><td>▁▅▅▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇█████████████████▇</td></tr><tr><td>val_auc</td><td>▁▁▂▃▅▆▆▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇█████████████▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>100</td></tr><tr><td>test_auc</td><td>0.71895</td></tr><tr><td>test_f1</td><td>0.6451</td></tr><tr><td>test_precision</td><td>0.59114</td></tr><tr><td>test_recall</td><td>0.70991</td></tr><tr><td>train_auc</td><td>0.71635</td></tr><tr><td>val_auc</td><td>0.71583</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">wandering-sweep-15</strong> at: <a href='https://wandb.ai/katrinpochtar/churn-prediction/runs/jhk3pggu' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction/runs/jhk3pggu</a><br> View project at: <a href='https://wandb.ai/katrinpochtar/churn-prediction' target="_blank">https://wandb.ai/katrinpochtar/churn-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251217_070959-jhk3pggu/logs</code>
